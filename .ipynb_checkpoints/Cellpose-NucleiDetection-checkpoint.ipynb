# %% [markdown]
# # Detection DAPI

# %% [markdown]
# ## Les installations (partie 1):

# %%
# !pip install cellpose
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# !pip uninstall torch

# %% [markdown]
# ## Les installations (partie 2):

# %%
# !conda install pytorch cudatoolkit=10.2 -c pytorch
# !pip install --no-deps cellpose --upgrade

# %% [markdown]
# ## Les imports:

# %%
from tkinter import *
from tkinter.filedialog import askdirectory
from tkinter.filedialog import askopenfilename
import os
from math import sqrt
import re
import matplotlib.pyplot as plt
import glob 
import cv2 as cv # to open and view your image
import cellpose
from cellpose import utils, io, plot, models

from skimage.io import imread
from skimage import filters
# Out:
# creating new log file
# 2022-01-31 17:05:05,696 [INFO] WRITING LOG OUTPUT TO C:\Users\silvinm\.cellpose\run.log

# %% [markdown]
# ## Choose your path directory / Create a Result directory

# %%
root = Tk()
root.withdraw()

# =============================================================================
#Choose your path directory
# =============================================================================
path = askdirectory(title='Select Working Folder') # shows dialog box and return the path
print(path)
os.chdir(path)

pathResult = path+'/Results'
if not os.path.exists(pathResult):
    os.makedirs(pathResult)
print(pathResult)

# =============================================================================
#Display files in the folder
# =============================================================================

list = os.listdir(path)
for fichiers in list:
    print(fichiers)
# Out:
# C:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI
# C:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI/Results
# Auxin+PB_1.tif
# Auxin+PB_1_cp_masks.png
# Auxin+PB_1_cp_outlines.txt
# Auxin+PB_2.tif
# Auxin+PB_2_cp_masks.png
# Auxin+PB_2_cp_outlines.txt
# Auxin+PB_Stack_1.tif
# Auxin_1.tif
# Auxin_1_cp_masks.png
# Auxin_1_cp_outlines.txt
# Auxin_2.tif
# Auxin_2_cp_masks.png
# Auxin_2_cp_outlines.txt
# Auxin_Stack__2.tif
# Crtl+PB_1.tif
# Crtl+PB_1_cp_masks.png
# Crtl+PB_1_cp_outlines.txt
# Crtl+PB_2.tif
# Crtl+PB_2_cp_masks.png
# Crtl+PB_2_cp_outlines.txt
# Crtl+PB_Stack_1.tif
# Crtl-1.tif
# Crtl-1_cp_masks.png
# Crtl-1_cp_outlines.txt
# Crtl-2.tif
# Crtl-2_cp_masks.png
# Crtl-2_cp_outlines.txt
# Crtl_Stack_1.tif
# Results

# %% [markdown]
# ## Run detection and segmentation

# %%
# =============================================================================
# Run Cellpose
# =============================================================================

model = models.Cellpose(gpu=False, model_type='cyto')


Impath = glob.glob(path+"/*.tif")
for img in Impath:
    image = imread(img)
    imgs = cv.imread(img,0)
    
    imageS = image.shape
    
    if len(imageS) > 3:
        print("Ne pas prendre en compte"+img)
    else:
    
        channel3 = image[:,:,2]

        GB_imgs = filters.gaussian(channel3, 2)
       # define CHANNELS to run segementation on
       # grayscale=0, R=1, G=2, B=3
       # channels = [cytoplasm, nucleus]
       # if NUCLEUS channel does not exist, set the second channel to 0
        channels = [0,0]

        # if diameter is set to None, the size of the cells is estimated on a per image basis
        # you can set the average cell `diameter` in pixels yourself (recommended)
        # diameter can be a list or a single number for all images

        masks, flows, styles, diams = model.eval(GB_imgs, diameter=70, channels=channels)
    #     masks, flows, styles, diams = model.eval(imgs, diameter=None, channels=channels)


        fig = plt.figure(figsize=(12,5))
        plot.show_segmentation(fig, GB_imgs, masks,flows[0],channels=channels)
        plt.tight_layout()
        plt.show()

        # image_name is file name of image
        # masks is numpy array of masks for image
        base = os.path.splitext(img)[0]
    #     outlines = utils.outlines_list(masks)
    #     io.outlines_to_text(base, outlines)
        io.save_to_png(imgs, masks, flows, img)
# Out:
# 2022-01-31 17:22:36,542 [INFO] >>>> using CPU
# 2022-01-31 17:22:36,618 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:22:42,261 [WARNING] WARNING: not interp
# 2022-01-31 17:22:42,860 [INFO] estimated cell diameter(s) in 6.24 sec
# 2022-01-31 17:22:42,861 [INFO] >>> diameter(s) =
# 2022-01-31 17:22:42,861 [INFO] [ 70.68 ]
# 2022-01-31 17:22:42,862 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:22:50,501 [INFO] >>>> TOTAL TIME 13.88 sec
# 2022-01-31 17:22:50,941 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:22:56,666 [WARNING] WARNING: not interp
# 2022-01-31 17:22:57,212 [INFO] estimated cell diameter(s) in 6.27 sec
# 2022-01-31 17:22:57,212 [INFO] >>> diameter(s) =
# 2022-01-31 17:22:57,213 [INFO] [ 66.56 ]
# 2022-01-31 17:22:57,214 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:23:04,939 [INFO] >>>> TOTAL TIME 14.00 sec
# Ne pas prendre en compteC:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI\Auxin+PB_Stack_1.tif
# 2022-01-31 17:23:05,381 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:23:11,161 [WARNING] WARNING: not interp
# 2022-01-31 17:23:11,738 [INFO] estimated cell diameter(s) in 6.36 sec
# 2022-01-31 17:23:11,739 [INFO] >>> diameter(s) =
# 2022-01-31 17:23:11,739 [INFO] [ 70.29 ]
# 2022-01-31 17:23:11,740 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:23:19,432 [INFO] >>>> TOTAL TIME 14.05 sec
# 2022-01-31 17:23:19,868 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:23:25,497 [WARNING] WARNING: not interp
# 2022-01-31 17:23:26,094 [INFO] estimated cell diameter(s) in 6.23 sec
# 2022-01-31 17:23:26,095 [INFO] >>> diameter(s) =
# 2022-01-31 17:23:26,096 [INFO] [ 77.77 ]
# 2022-01-31 17:23:26,097 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:23:30,020 [INFO] >>>> TOTAL TIME 10.15 sec
# Ne pas prendre en compteC:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI\Auxin_Stack__2.tif
# 2022-01-31 17:23:30,451 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:23:36,107 [WARNING] WARNING: not interp
# 2022-01-31 17:23:36,616 [INFO] estimated cell diameter(s) in 6.17 sec
# 2022-01-31 17:23:36,617 [INFO] >>> diameter(s) =
# 2022-01-31 17:23:36,617 [INFO] [ 65.92 ]
# 2022-01-31 17:23:36,618 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:23:44,289 [INFO] >>>> TOTAL TIME 13.84 sec
# 2022-01-31 17:23:44,706 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:23:50,508 [WARNING] WARNING: not interp
# 2022-01-31 17:23:51,038 [INFO] estimated cell diameter(s) in 6.33 sec
# 2022-01-31 17:23:51,039 [INFO] >>> diameter(s) =
# 2022-01-31 17:23:51,040 [INFO] [ 61.90 ]
# 2022-01-31 17:23:51,040 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:23:58,567 [INFO] >>>> TOTAL TIME 13.86 sec
# Ne pas prendre en compteC:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI\Crtl+PB_Stack_1.tif
# 2022-01-31 17:23:58,992 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:24:04,804 [WARNING] WARNING: not interp
# 2022-01-31 17:24:05,398 [INFO] estimated cell diameter(s) in 6.41 sec
# 2022-01-31 17:24:05,398 [INFO] >>> diameter(s) =
# 2022-01-31 17:24:05,398 [INFO] [ 69.92 ]
# 2022-01-31 17:24:05,399 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:24:13,234 [INFO] >>>> TOTAL TIME 14.24 sec
# 2022-01-31 17:24:13,692 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2022-01-31 17:24:19,469 [WARNING] WARNING: not interp
# 2022-01-31 17:24:19,989 [INFO] estimated cell diameter(s) in 6.30 sec
# 2022-01-31 17:24:19,989 [INFO] >>> diameter(s) =
# 2022-01-31 17:24:19,990 [INFO] [ 67.13 ]
# 2022-01-31 17:24:19,991 [INFO] ~~~ FINDING MASKS ~~~
# 2022-01-31 17:24:27,862 [INFO] >>>> TOTAL TIME 14.17 sec
# Ne pas prendre en compteC:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI\Crtl_Stack_1.tif

# %%
#Moving png and txt from folder

import shutil

pngpath = glob.glob(path+"/*.png")
for files in pngpath:
     original = r'original path where the file is currently stored\file name.file extension'
     target = r'target path where the file will be moved\file name.file extension'
    shutil.move(path,pathResult)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\.conda\envs\cellpose\lib\shutil.py in move(src, dst, copy_function)
#     790     try:
# --> 791         os.rename(src, real_dst)
#     792     except OSError:
#
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI' -> 'C:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI/Results\\DAPI'
#
# During handling of the above exception, another exception occurred:
#
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10892/1432300987.py in <module>
#       7 #     original = r'original path where the file is currently stored\file name.file extension'
#       8 #     target = r'target path where the file will be moved\file name.file extension'
# ----> 9     shutil.move(path,pathResult)
#      10
#      11
#
# ~\.conda\envs\cellpose\lib\shutil.py in move(src, dst, copy_function)
#     797         elif os.path.isdir(src):
#     798             if _destinsrc(src, dst):
# --> 799                 raise Error("Cannot move a directory '%s' into itself"
#     800                             " '%s'." % (src, dst))
#     801             if (_is_immutable(src)
#
# Error: Cannot move a directory 'C:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI' into itself 'C:/Users/silvinm/Desktop/Faezeh_Detection_noyaux_measure_intensity/DAPI/Results'.
